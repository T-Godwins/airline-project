# %%
# %pip install scrapy selenium scrapy-selenium webdriver-manager

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
# Out:
# 2025-03-17 20:08:12 [numexpr.utils] INFO: NumExpr defaulting to 8 threads.

# %%
# Navigate to TripAdvisor
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')  # Run in headless mode
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36')
chrome_options.add_experimental_option('excludeSwitches', ['enable-automation'])
chrome_options.add_experimental_option('useAutomationExtension', False)

driver = webdriver.Chrome(options=chrome_options)
original_url = "https://www.airlinequality.com/airline-reviews/delta-air-lines/page/312/"
driver.get(original_url)

# List of article names and links 
title = ""


r = requests.get(original_url)
soup = BeautifulSoup(r.content, "html.parser")
results = soup.find("div", {"id": "content", "itemtype": "http://schema.org/Airline"})
title = results.find("div", class_="info").find("h1", itemprop="name").text.strip()

    
driver.close()
# Out:
# 2025-03-17 20:32:22 [selenium.webdriver.common.selenium_manager] DEBUG: Selenium Manager binary found at: /opt/homebrew/anaconda3/lib/python3.12/site-packages/selenium/webdriver/common/macos/selenium-manager
# 2025-03-17 20:32:22 [selenium.webdriver.common.selenium_manager] DEBUG: Executing process: /opt/homebrew/anaconda3/lib/python3.12/site-packages/selenium/webdriver/common/macos/selenium-manager --browser chrome --language-binding python --output json
# 2025-03-17 20:32:24 [selenium.webdriver.common.selenium_manager] DEBUG: Driver path: /Users/godwinstuyishime/.cache/selenium/chromedriver/mac-arm64/134.0.6998.88/chromedriver
# 2025-03-17 20:32:24 [selenium.webdriver.common.selenium_manager] DEBUG: Browser path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
# ...

# %%
# Make a DF with article names and lists and export
print(title)
# Out:
# Delta Air Lines

# %%
# %pip install twitter-scraper
from twitter_scraper import get_tweets

for tweet in get_tweets('twitter', pages=1):
    print(tweet['text'])
    break
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[33], line 2
#       1 # %pip install twitter-scraper
# ----> 2 from twitter_scraper import get_tweets
#       4 for tweet in get_tweets('twitter', pages=1):
#       5     print(tweet['text'])
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/twitter_scraper/__init__.py:1
# ----> 1 from .modules.profile import Profile
#       2 from .modules.tweets import get_tweets
#       3 from .modules.trends import get_trends
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/twitter_scraper/modules/profile.py:1
# ----> 1 from requests_html import HTMLSession, HTML
#       2 from lxml.etree import ParserError
#       4 session = HTMLSession()
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests_html.py:14
#      11 from pyquery import PyQuery
#      13 from fake_useragent import UserAgent
# ...
